# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from scipy import stats
import numpy as np
from sklearn.metrics import r2_score
from sklearn import linear_model

# %%
data = pd.read_excel('data2.xlsx')
data.head(10)
# Out:
#     Age  gender  chest_pain_type  Resting_BP  Cholestrol  Fasting_sugar  \
# 0  70.0     1.0                4       130.0       322.0            0.0
# 1  67.0     0.0                3       115.0       564.0            0.0
# 2  57.0     1.0                2       124.0       261.0            0.0
# 3  64.0     1.0                4       128.0       263.0            0.0
# 4  74.0     0.0                2       120.0       269.0            0.0
# 5  65.0     1.0                4       120.0       177.0            0.0
# 6  56.0     1.0                3         NaN       256.0            1.0
# 7  59.0     1.0                4       110.0       239.0            0.0
# 8  60.0     1.0                4         NaN       293.0            0.0
# 9  63.0     0.0                4       150.0       407.0            0.0
#
#    Resting_ECG  Max_heart_rate  Exercise_induced_angina  ST_Depression  \
# 0          2.0           109.0                      0.0            2.4
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      267 non-null    float64
#  1   gender                   268 non-null    float64
#  2   chest_pain_type          270 non-null    int64
#  3   Resting_BP               266 non-null    float64
#  4   Cholestrol               267 non-null    float64
#  5   Fasting_sugar            266 non-null    float64
#  6   Resting_ECG              265 non-null    float64
#  7   Max_heart_rate           266 non-null    float64
#  8   Exercise_induced_angina  267 non-null    float64
#  9   ST_Depression            265 non-null    float64
#  10  Slope_peak_excercise     266 non-null    float64
#  11  No_of_major_vessels      264 non-null    float64
#  12  Thal                     262 non-null    float64
# ...

# %%
data.describe()
# Out:
#               Age      gender  chest_pain_type  Resting_BP  Cholestrol  \
# count  267.000000  268.000000       270.000000  266.000000  267.000000
# mean    54.411985    0.679104         3.174074  131.424812  250.318352
# std      9.182502    0.467694         0.946169   17.902988   51.430073
# min     29.000000    0.000000         1.000000   94.000000  126.000000
# 25%     47.000000    0.000000         3.000000  120.000000  214.000000
# 50%     55.000000    1.000000         3.000000  130.000000  245.000000
# 75%     61.000000    1.000000         4.000000  140.000000  281.500000
# max     77.000000    1.000000         4.000000  200.000000  564.000000
#
#        Fasting_sugar  Resting_ECG  Max_heart_rate  Exercise_induced_angina  \
# count     266.000000   265.000000      266.000000               267.000000
# mean        0.142857     1.018868      150.195489                 0.333333
# std         0.350587     0.997925       23.200832                 0.472290
# ...

# %%
fig = px.histogram(data, x='Age', marginal='box', title="Age Distribution")
fig.show()

# %%
fig = px.histogram(data, x='gender', marginal='box',nbins=47, title="Age Distribution")
fig.show()

# %%
fig = px.histogram(data, x='chest_pain_type', marginal='box',nbins=47, title="Age Distribution")
fig.show()

# %%
fig = px.histogram(data, x='Resting_BP', marginal='box',nbins=47, title="Age Distribution")
fig.show()

# %%
fig = px.histogram(data, x='Resting_BP', marginal='box',color='Disease', title="Bp Distribution")
fig.show()

# %%
fig = px.histogram(data, x='gender', marginal='box',color='Disease')
fig.show()

# %%
fig  = px.scatter(data, x='Age', opacity=0.8, y='Resting_BP', title='Age with disease')
fig.show()

# %%
fig = px.violin(data, x='gender', y='Disease')
fig.show()

# %%
data.corr()
# Out:
#                               Age    gender  chest_pain_type  Resting_BP  \
# Age                      1.000000 -0.102837         0.101294    0.269385
# gender                  -0.102837  1.000000         0.034425   -0.065835
# chest_pain_type          0.101294  0.034425         1.000000   -0.046849
# Resting_BP               0.269385 -0.065835        -0.046849    1.000000
# Cholestrol               0.217525 -0.195462         0.078225    0.170916
# Fasting_sugar            0.130233  0.021319        -0.096937    0.159996
# Resting_ECG              0.131906  0.021353         0.072532    0.097491
# Max_heart_rate          -0.431773 -0.063548        -0.321149   -0.037386
# Exercise_induced_angina  0.091526  0.185724         0.335610    0.090064
# ST_Depression            0.190862  0.094231         0.177330    0.220402
# Slope_peak_excercise     0.158367  0.064616         0.145534    0.135304
# No_of_major_vessels      0.377173  0.068685         0.240491    0.084954
# ...

# %%
sns.heatmap(data[['Age', 'gender', 'chest_pain_type', 'Resting_BP', 'Cholestrol',
                  'Fasting_sugar', 'Resting_ECG', 'Max_heart_rate',
                  'Exercise_induced_angina', 'ST_Depression', 
                  'Slope_peak_excercise', 'No_of_major_vessels', 
                  'Thal', 'Disease']].corr(), annot=True, cmap='coolwarm')
plt.figure(figsize=(14,7))
plt.show()

# %%
x = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]
y = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]
plt.scatter(x,y)
plt.show()

# %%
x = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]
y = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]

slope, intercept, r, p, std_err = stats.linregress(x,y)

def myfunc(x):
    return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x,y)
plt.plot(x, mymodel)
plt.show()

# %%
x = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]
y = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]

slope, intercept, r, p, std_err = stats.linregress(x,y)

print(r)
# Out:
# -0.758591524376155

# %%
x = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]
y = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]

slope, intercept, r, p, std_err = stats.linregress(x,y)

def myfunc(x):
    return slope * x + intercept

speed = myfunc(10)
print(speed)
# Out:
# 85.59308314937454

# %%
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

slope, intercept, r, p, std_err = stats.linregress(x,y)

def myfunc(x):
    return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x,y)
plt.plot(x, mymodel)
plt.show()

# %%
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

slope, intercept, r, p, std_err = stats.linregress(x,y)

print(r)
# Out:
# 0.01331814154297491

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]
plt.scatter(x,y)
plt.show()

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = np.poly1d(np.polyfit(x, y, 1))

myline = np.linspace(1, 22, 100)

plt.scatter(x,y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = np.poly1d(np.polyfit(x, y, 2))

myline = np.linspace(1, 22, 100)

plt.scatter(x,y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = np.poly1d(np.polyfit(x, y, 3))

myline = np.linspace(1, 22, 100)

plt.scatter(x,y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = np.poly1d(np.polyfit(x, y, 3))

print(r2_score(y, mymodel(x)))
# Out:
# 0.9432150416451026

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = np.poly1d(np.polyfit(x, y, 3))

speed = mymodel(17)
print(speed)
# Out:
# 88.87331269698001

# %%
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

mymodel = np.poly1d(np.polyfit(x, y, 3))

myline = np.linspace(2, 95, 100)

plt.scatter(x,y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

mymodel = np.poly1d(np.polyfit(x, y, 3))

print(r2_score(y, mymodel(x)))
# Out:
# 0.009952707566680652

# %%
x = data[['Age', 'gender', 'chest_pain_type', 'Resting_BP', 'Cholestrol',
                  'Fasting_sugar', 'Resting_ECG', 'Max_heart_rate',
                  'Exercise_induced_angina',  'Thal']]
y = data['Disease']

regr = linear_model.LinearRegression()
regr.fit(x,y)

print(regr.coef_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 7
#       4 y = data['Disease']
#       6 regr = linear_model.LinearRegression()
# ----> 7 regr.fit(x,y)
#       9 print(regr.coef_)
#
# File C:\Python310\lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File C:\Python310\lib\site-packages\sklearn\linear_model\_base.py:601, in LinearRegression.fit(self, X, y, sample_weight)
#     597 n_jobs_ = self.n_jobs
#     599 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 601 X, y = validate_data(
# ...

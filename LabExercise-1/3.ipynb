# %%
numbers = []

for i in range(3):
    num = int(input("Enter a number: "))
    numbers.append(num)

t = tuple(numbers)
a, b, c = t
print(a)
print(b)
print(c)
# Out:
# Enter a number:  6
# Enter a number:  1
# Enter a number:  9
# 6
# 1
# 9
